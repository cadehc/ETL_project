# %%
import pandas as pd

# %%
#Areas csv
areas = "Resources/Areas.csv"
areas_df = pd.read_csv(areas, encoding="utf-8")
areas_df.head()
# Out:
#   ID_NQN                NOMBRE     BLOQUE  \
# 0   A155  RINCON DEL MANGRULLO        NaN
# 1   A152        PUESTO TOUQUET        NaN
# 2   A148      PUESTO CORTADERA        NaN
# 3   A147      PORTEZUELO MINAS        NaN
# 4   A120         LOMA NEGRA NI  BLOQUE II
#
#                                   TIPO_AREA                          TITULAR  \
# 0  CONCESION DE EXPLOTACION NO CONVENCIONAL                         YPF S.A.
# 1                  CONCESION DE EXPLOTACION           Geopark Argentina LTD.
# 2                  CONCESION DE EXPLOTACION  Gas y Petroleo del Neuquen S.A.
# 3                  CONCESION DE EXPLOTACION  Gas y Petroleo del Neuquen S.A.
# 4                  CONCESION DE EXPLOTACION  Gas y Petroleo del Neuquen S.A.
#
#                                   PARTICIPAC                OPERADOR  \
# 0                             YPF S.A (100%)                YPF S.A.
# 1          Geopark Argentina LTD. (100.00 %)  GEOPARK ARGENTINA LTD.
# ...

# %%
#Pozos csv
pozos = "Resources/Pozos.csv"
pozos_df = pd.read_csv(pozos, encoding="utf-8")
pozos_df.head()
# Out:
#   WELL_ID       WELL_NAME WELL_SHORT_NAME      FIELD_NAME OFFICIAL_STATUS  \
# 0  P00012  PEL.Nq.BoMo-14         BoMo-14  Borde Mocho 14             EEF
# 1  P00047     PPC.Nq.EC-2            EC-2    El Caracol 2               A
# 2  P00049     PPC.Nq.EC-4            EC-4    El Caracol 4             EEF
# 3  P00052     PPC.Nq.EC-7            EC-7    El Caracol 7             EIE
# 4  P00055    PPC.Nq.EC-10           EC-10   El Caracol 10              ES
#
#   STATUS_IN_GIS ORIGINAL_STATUS          PRODUCTION_SYSTEM FLUID  \
# 0        Activo      Productivo            Bombeo mecanico   PET
# 1    Abandonado             NaN  Sin sistema de extraccion   PET
# 2        Activo      Productivo            Bombeo mecanico   PET
# 3        Activo      Productivo  Otros tipos de extraccion   AGU
# 4      Inactivo             NaN  Sin sistema de extraccion   PET
#
#   WELL_GEOMETRY  ... HAS_DESVIATION_SURVEY HAS_LABORATORY_STUDY  \
# ...
